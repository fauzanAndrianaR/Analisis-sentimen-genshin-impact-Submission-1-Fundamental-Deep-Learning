# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
app_id = 'com.miHoYo.GenshinImpact'
count = 55000
all_reviews = []
continuation_token = None

while len(all_reviews) < count:
    review_batch, continuation_token = reviews(
        app_id,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=500,
        continuation_token=continuation_token
    )

    if not review_batch:
        break

    all_reviews.extend(review_batch)
    print(f"Total reviews collected: {len(all_reviews)}")

    if continuation_token is None:
        break
# Out:
# Total reviews collected: 500
# Total reviews collected: 1000
# Total reviews collected: 1500
# Total reviews collected: 2000
# Total reviews collected: 2500
# Total reviews collected: 3000
# Total reviews collected: 3500
# Total reviews collected: 4000
# Total reviews collected: 4500
# Total reviews collected: 5000
# Total reviews collected: 5500
# Total reviews collected: 6000
# Total reviews collected: 6500
# Total reviews collected: 7000
# Total reviews collected: 7500
# Total reviews collected: 8000
# Total reviews collected: 8500
# Total reviews collected: 9000
# Total reviews collected: 9500
# Total reviews collected: 10000
# Total reviews collected: 10500
# Total reviews collected: 11000
# Total reviews collected: 11500
# Total reviews collected: 12000
# Total reviews collected: 12500
# Total reviews collected: 13000
# Total reviews collected: 13500
# Total reviews collected: 14000
# Total reviews collected: 14500
# Total reviews collected: 15000
# Total reviews collected: 15500
# Total reviews collected: 16000
# Total reviews collected: 16500
# Total reviews collected: 17000
# Total reviews collected: 17500
# Total reviews collected: 18000
# Total reviews collected: 18500
# Total reviews collected: 19000
# Total reviews collected: 19500
# Total reviews collected: 20000
# Total reviews collected: 20500
# Total reviews collected: 21000
# Total reviews collected: 21500
# Total reviews collected: 22000
# Total reviews collected: 22500
# Total reviews collected: 23000
# Total reviews collected: 23500
# Total reviews collected: 24000
# Total reviews collected: 24500
# Total reviews collected: 25000
# Total reviews collected: 25500
# Total reviews collected: 26000
# Total reviews collected: 26500
# Total reviews collected: 27000
# Total reviews collected: 27500
# Total reviews collected: 28000
# Total reviews collected: 28500
# Total reviews collected: 29000
# Total reviews collected: 29500
# Total reviews collected: 30000
# Total reviews collected: 30500
# Total reviews collected: 31000
# Total reviews collected: 31500
# Total reviews collected: 32000
# Total reviews collected: 32500
# Total reviews collected: 33000
# Total reviews collected: 33500
# Total reviews collected: 34000
# Total reviews collected: 34500
# Total reviews collected: 35000
# Total reviews collected: 35500
# Total reviews collected: 36000
# Total reviews collected: 36500
# Total reviews collected: 37000
# Total reviews collected: 37500
# Total reviews collected: 38000
# Total reviews collected: 38500
# Total reviews collected: 39000
# Total reviews collected: 39500
# Total reviews collected: 40000
# Total reviews collected: 40500
# Total reviews collected: 41000
# Total reviews collected: 41500
# Total reviews collected: 42000
# Total reviews collected: 42500
# Total reviews collected: 43000
# Total reviews collected: 43500
# Total reviews collected: 44000
# Total reviews collected: 44500
# Total reviews collected: 45000
# Total reviews collected: 45500
# Total reviews collected: 46000
# Total reviews collected: 46500
# Total reviews collected: 47000
# Total reviews collected: 47500
# Total reviews collected: 48000
# Total reviews collected: 48500
# Total reviews collected: 49000
# Total reviews collected: 49500
# Total reviews collected: 50000
# Total reviews collected: 50500
# Total reviews collected: 51000
# Total reviews collected: 51500
# Total reviews collected: 52000
# Total reviews collected: 52500
# Total reviews collected: 53000
# Total reviews collected: 53500
# Total reviews collected: 54000
# Total reviews collected: 54500
# Total reviews collected: 55000

# %%
df = pd.DataFrame(all_reviews)

# %%
df.head()
# Out:
#                                reviewId          userName  \
# 0  77127819-e8cd-40ab-a7f4-9bb77679dab7      Akshay Kumar
# 1  be32da3c-11df-4f8c-ad6d-d6a63ca81e48             Keiko
# 2  614e119d-093f-46f4-a14c-d1e12e1758c3     Jocelyn Ragas
# 3  5346f4f1-6d6d-4569-a194-8c6106ac5a3f  Liza Jortmenadze
# 4  ef22584e-6c2f-444b-8c2d-40f7598c4b62         omo omo90
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  best game ever but please set one main charact...      5              1
# 1  bro everything is fan service, all female like...      1              9
# 2                                        nicre 10 10      5              0
# 3  the game is really good but there's a lot of -...      2              5
# 4  i played it before, it sucks. i didnt find the...      1             10
#
#       reviewCreatedVersion                  at replyContent repliedAt  \
# 0                     None 2025-04-12 13:45:52         None       NaT
# 1  5.5.0_31400259_31451966 2025-04-12 12:55:23         None       NaT
# 2  5.5.0_31400259_31451966 2025-04-09 13:15:20         None       NaT
# 3  5.5.0_31400259_31451966 2025-04-09 13:06:10         None       NaT
# 4                     None 2025-04-09 13:03:51         None       NaT
#
#                 appVersion
# 0                     None
# 1  5.5.0_31400259_31451966
# 2  5.5.0_31400259_31451966
# 3  5.5.0_31400259_31451966
# 4                     None

# %%
df.tail()
# Out:
#                                    reviewId         userName  \
# 54995  1f4c1174-a99f-4d1c-8d18-178d2587c8b7    Felize Derain
# 54996  1aae0531-1877-435b-a74a-ab72d5ed621b      Aviel Iliya
# 54997  a764a77b-5a33-49b3-aff2-89b89e346712  Emilia nyamandi
# 54998  175b79ea-47e1-4687-9fbb-bbac1487d171            Hi Uj
# 54999  84989073-e0c2-4076-997c-6732a7226220      Aryan Arora
#
#                                                userImage  \
# 54995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 54996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 54998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 54999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                  content  score  \
# 54995  The story line, characters, quality, EVERYTHIN...      3
# 54996       Incredible I have been waiting for atlechino      5
# 54997                                 Wow Genshin impact      5
# 54998                                          So greedy      3
# 54999  The graphic are really good but the size is to...      5
#
#        thumbsUpCount     reviewCreatedVersion                  at  \
# 54995              0                     None 2024-04-25 17:42:19
# 54996              1  4.5.0_21307647_21321795 2024-04-25 17:35:32
# 54997              0                     None 2024-04-25 17:32:06
# 54998              0  4.6.0_22174900_22378599 2024-04-25 17:28:58
# 54999              0  4.6.0_22174900_22378599 2024-04-25 17:22:59
#
#       replyContent repliedAt               appVersion
# 54995         None       NaT                     None
# 54996         None       NaT  4.5.0_21307647_21321795
# 54997         None       NaT                     None
# 54998         None       NaT  4.6.0_22174900_22378599
# 54999         None       NaT  4.6.0_22174900_22378599

# %%
df.describe()
# Out:
#               score  thumbsUpCount                             at  \
# count  55000.000000    55000.00000                          55000
# mean       3.479527        4.47320  2024-10-03 23:35:24.603836160
# min        1.000000        0.00000            2024-04-25 17:22:59
# 25%        1.000000        0.00000     2024-07-15 18:33:33.500000
# 50%        5.000000        0.00000            2024-09-15 08:45:51
# 75%        5.000000        1.00000            2025-01-01 03:42:36
# max        5.000000     4564.00000            2025-04-12 13:45:52
# std        1.796158       56.22009                            NaN
#
#                            repliedAt
# count                           6734
# mean   2024-10-01 22:08:18.925750016
# min              2021-03-17 00:53:26
# 25%    2024-09-30 08:54:19.249999872
# 50%              2024-11-21 18:52:03
# 75%              2025-02-18 21:57:51
# max              2025-03-26 18:20:33
# std                              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              55000 non-null  object
#  1   userName              55000 non-null  object
#  2   userImage             55000 non-null  object
#  3   content               54995 non-null  object
#  4   score                 55000 non-null  int64
#  5   thumbsUpCount         55000 non-null  int64
#  6   reviewCreatedVersion  37478 non-null  object
#  7   at                    55000 non-null  datetime64[ns]
#  8   replyContent          6734 non-null   object
#  9   repliedAt             6734 non-null   datetime64[ns]
#  10  appVersion            37478 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 4.6+ MB

# %%
# Simpan ke CSV
df[['userName', 'score', 'content', 'at']].to_csv("genshin_reviews.csv", index=False)
